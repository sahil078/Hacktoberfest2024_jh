# %% [markdown]
# ### 1. Write a Python function called `is_even` that takes an integer as an argument and returns `True` if the number is even, and `False` if it is odd.
#
# **Example Input:** `is_even(10)`
# **Expected Output:** `True`

# %% [markdown]
# ### 2. Create a function `fibonacci(n)` that returns the first `n` numbers in the Fibonacci sequence.
#
# **Example Input:** `fibonacci(5)`
# **Expected Output:** `[0, 1, 1, 2, 3]`

# %% [markdown]
# ### 3. Write a Python program that reads a list of numbers and returns the maximum number from the list.
#
# **Example Input:** `[1, 5, 3, 9, 2]`
# **Expected Output:** `9`

# %% [markdown]
# ### 4. Create a function `count_vowels(s)` that counts the number of vowels in a given string `s`.
#
# **Example Input:** `count_vowels('hello world')`
# **Expected Output:** `3`

# %% [markdown]
# ### 5. Write a program that reverses a string without using the built-in `reverse` method.
#
# **Example Input:** `'Python'`
# **Expected Output:** `'nohtyP'`

# %% [markdown]
# ### 6. Implement a function `remove_duplicates(lst)` that removes duplicate values from a list and returns a new list.
#
# **Example Input:** `remove_duplicates([1, 2, 3, 2, 1])`
# **Expected Output:** `[1, 2, 3]`

# %% [markdown]
# ### 7. Create a function `find_prime(n)` that returns `True` if `n` is a prime number and `False` otherwise.
#
# **Example Input:** `find_prime(7)`
# **Expected Output:** `True`

# %% [markdown]
# ### 8. Write a Python program to find the factorial of a number using recursion.
#
# **Example Input:** `factorial(5)`
# **Expected Output:** `120`

# %% [markdown]
# ### 9. Create a function `sort_list(lst)` that sorts a list of numbers in ascending order without using the built-in `sort` method.
#
# **Example Input:** `sort_list([3, 1, 4, 1, 5, 9])`
# **Expected Output:** `[1, 1, 3, 4, 5, 9]`

# %% [markdown]
# ### 10. Write a program that checks whether a string is a palindrome (reads the same forwards and backwards).
#
# **Example Input:** `is_palindrome('racecar')`
# **Expected Output:** `True`
